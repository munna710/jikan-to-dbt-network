# %%
import requests
import psycopg2
from time import sleep
from datetime import datetime

# %%
# Jikan API base URL and delay
JIKAN_BASE_URL = "https://api.jikan.moe/v4"
RATE_LIMIT_DELAY = 1.5  # seconds

# %%
# PostgreSQL connection
conn = psycopg2.connect(
    dbname="anime_db",
    user="root",
    password="root",
    host="localhost"
)
cursor = conn.cursor()

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS anime (
    anime_id INT PRIMARY KEY,
    title TEXT,
    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
    updated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
);
""")

cursor.execute("""
CREATE TABLE IF NOT EXISTS staff (
    staff_id INT PRIMARY KEY,
    name TEXT,
    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
    updated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
);
""")

cursor.execute("""
CREATE TABLE IF NOT EXISTS staff_roles (
    anime_id INT,
    staff_id INT,
    role TEXT,
    PRIMARY KEY (anime_id, staff_id, role),
    FOREIGN KEY (anime_id) REFERENCES anime(anime_id),
    FOREIGN KEY (staff_id) REFERENCES staff(staff_id),
    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
    updated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
    
);
""")

cursor.execute("""
CREATE TABLE IF NOT EXISTS anime_ratings (
    anime_id INT PRIMARY KEY,
    rating FLOAT,
    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
    updated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
    FOREIGN KEY (anime_id) REFERENCES anime(anime_id)
);
""")

conn.commit()

# %%
def get_anime_details(anime_id):
    """Fetch anime title and rating using Jikan"""
    try:
        response = requests.get(f"{JIKAN_BASE_URL}/anime/{anime_id}")
        response.raise_for_status()
        data = response.json().get("data", {})
        title = data.get("title")
        rating = data.get("score")  # Might be None
        return title, rating
    except Exception as e:
        print(f"[!] Failed to get anime details {anime_id}: {e}")
        return f"Anime {anime_id}", None

# %%
def get_anime_staff(anime_id):
    """Fetch staff data for a specific anime from Jikan API"""
    try:
        response = requests.get(f"{JIKAN_BASE_URL}/anime/{anime_id}/staff")
        response.raise_for_status()
        return response.json().get("data", [])
    except Exception as e:
        print(f"[!] Failed to get staff for anime {anime_id}: {e}")
        return []

# %%
def insert_data(conn, anime_id, title, staff_data, rating):
    with conn.cursor() as cursor:
        try:
            # Insert anime
            cursor.execute("""
                INSERT INTO anime (anime_id, title)
                VALUES (%s, %s)
                ON CONFLICT (anime_id) DO UPDATE SET
                    title = EXCLUDED.title,
                    updated_at = CURRENT_TIMESTAMP;
            """, (anime_id, title))

            # Insert anime rating
            cursor.execute("""
                INSERT INTO anime_ratings (anime_id, rating)
                VALUES (%s, %s)
                ON CONFLICT (anime_id) DO UPDATE SET
                    rating = EXCLUDED.rating,
                    updated_at = CURRENT_TIMESTAMP;
            """, (anime_id, rating))

            # Insert staff and roles
            for staff in staff_data:
                staff_id = staff["person"]["mal_id"]
                name = staff["person"]["name"]
                roles = staff.get("positions", [])

                cursor.execute("""
                    INSERT INTO staff (staff_id, name)
                    VALUES (%s, %s)
                    ON CONFLICT (staff_id) DO UPDATE SET
                        name = EXCLUDED.name,
                        updated_at = CURRENT_TIMESTAMP;
                """, (staff_id, name))

                for role in roles:
                    cursor.execute("""
                        INSERT INTO staff_roles (anime_id, staff_id, role)
                        VALUES (%s, %s, %s)
                        ON CONFLICT (anime_id, staff_id, role) DO NOTHING;
                    """, (anime_id, staff_id, role))

            conn.commit()
            print(f"[✓] Inserted anime {anime_id}: {title} with rating {rating}")

        except Exception as e:
            conn.rollback()
            print(f"[✗] Error inserting anime {anime_id}: {e}")

# %%
def main(conn):
    START_ID = 1
    END_ID = 100

    try:
        for anime_id in range(START_ID, END_ID + 1):
            staff_data = get_anime_staff(anime_id)
            if not staff_data:
                continue

            title, rating = get_anime_details(anime_id)
            insert_data(conn, anime_id, title, staff_data, rating)
            sleep(RATE_LIMIT_DELAY)

    except Exception as e:
        print(f"[!] Fatal error: {e}")

# %%
main(conn)
# Out:
# [✓] Inserted anime 1: Cowboy Bebop with rating 8.75
# [!] Failed to get staff for anime 2: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/2/staff
# [!] Failed to get staff for anime 3: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/3/staff
# [!] Failed to get staff for anime 4: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/4/staff
# [✓] Inserted anime 5: Cowboy Bebop: Tengoku no Tobira with rating 8.38
# [✓] Inserted anime 6: Trigun with rating 8.22
# [✓] Inserted anime 7: Witch Hunter Robin with rating 7.24
# [✓] Inserted anime 8: Bouken Ou Beet with rating 6.93
# [!] Failed to get staff for anime 9: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/9/staff
# [!] Failed to get staff for anime 10: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/10/staff
# [!] Failed to get staff for anime 11: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/11/staff
# [!] Failed to get staff for anime 12: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/12/staff
# [!] Failed to get staff for anime 13: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/13/staff
# [!] Failed to get staff for anime 14: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/14/staff
# [✓] Inserted anime 15: Eyeshield 21 with rating 7.91
# [✓] Inserted anime 16: Hachimitsu to Clover with rating 7.98
# [✓] Inserted anime 17: Hungry Heart: Wild Striker with rating 7.54
# [✓] Inserted anime 18: Initial D Fourth Stage with rating 8.17
# [✓] Inserted anime 19: Monster with rating 8.89
# [✓] Inserted anime 20: Naruto with rating 8.01
# [✓] Inserted anime 21: One Piece with rating 8.73
# [✓] Inserted anime 22: Tennis no Oujisama with rating 7.85
# [✓] Inserted anime 23: Ring ni Kakero 1 with rating 6.35
# [✓] Inserted anime 24: School Rumble with rating 7.88
# [✓] Inserted anime 25: Sunabouzu with rating 7.36
# [✓] Inserted anime 26: Texhnolyze with rating 7.75
# [✓] Inserted anime 27: Trinity Blood with rating 7.28
# [✓] Inserted anime 28: Yakitate!! Japan with rating 7.91
# [✓] Inserted anime 29: Zipang with rating 7.49
# [✓] Inserted anime 30: Shinseiki Evangelion with rating 8.36
# [✓] Inserted anime 31: Shinseiki Evangelion Movie: Shi to Shinsei with rating 7.48
# [✓] Inserted anime 32: Shinseiki Evangelion Movie: Air/Magokoro wo, Kimi ni with rating 8.56
# [✓] Inserted anime 33: Kenpuu Denki Berserk with rating 8.6
# [!] Failed to get staff for anime 34: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/34/staff
# [!] Failed to get staff for anime 35: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/35/staff
# [!] Failed to get staff for anime 36: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/36/staff
# [!] Failed to get staff for anime 37: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/37/staff
# [!] Failed to get staff for anime 38: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/38/staff
# [!] Failed to get staff for anime 39: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/39/staff
# [!] Failed to get staff for anime 40: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/40/staff
# [!] Failed to get staff for anime 41: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/41/staff
# [!] Failed to get staff for anime 42: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/42/staff
# [✓] Inserted anime 43: Koukaku Kidoutai with rating 8.27
# [✓] Inserted anime 44: Rurouni Kenshin: Meiji Kenkaku Romantan - Tsuioku-hen with rating 8.7
# [✓] Inserted anime 45: Rurouni Kenshin: Meiji Kenkaku Romantan with rating 8.28
# [✓] Inserted anime 46: Rurouni Kenshin: Meiji Kenkaku Romantan - Ishinshishi e no Chinkonka with rating 7.55
# [✓] Inserted anime 47: Akira with rating 8.16
# [✓] Inserted anime 48: .hack//Sign with rating 6.94
# [✓] Inserted anime 49: Aa! Megami-sama! with rating 7.28
# [✓] Inserted anime 50: Aa! Megami-sama! (TV) with rating 7.31
# [✓] Inserted anime 51: Tenshi Kinryouku with rating 6.24
# [✓] Inserted anime 52: Kidou Tenshi Angelic Layer with rating 7.26
# [✓] Inserted anime 53: Ai Yori Aoshi with rating 7.1
# [✓] Inserted anime 54: Appleseed (Movie) with rating 7.05
# [✓] Inserted anime 55: Arc the Lad with rating 6.49
# [✓] Inserted anime 56: Avenger with rating 5.85
# [✓] Inserted anime 57: Beck with rating 8.29
# [✓] Inserted anime 58: Blue Gender with rating 7.01
# [✓] Inserted anime 59: Chobits with rating 7.39
# [✓] Inserted anime 60: Chrno Crusade with rating 7.6
# [✓] Inserted anime 61: D.N.Angel with rating 7.16
# [✓] Inserted anime 62: D.C.: Da Capo with rating 6.71
# [✓] Inserted anime 63: DearS with rating 6.54
# [✓] Inserted anime 64: Rozen Maiden with rating 7.4
# [✓] Inserted anime 65: Rozen Maiden: Träumend with rating 7.61
# [✓] Inserted anime 66: Azumanga Daiou The Animation with rating 8.06
# [✓] Inserted anime 67: Basilisk: Kouga Ninpou Chou with rating 7.53
# [✓] Inserted anime 68: Black Cat with rating 7.31
# [✓] Inserted anime 69: Cluster Edge with rating 6.31
# [!] Failed to get staff for anime 70: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/70/staff
# [✓] Inserted anime 71: Full Metal Panic! with rating 7.59
# [✓] Inserted anime 72: Full Metal Panic? Fumoffu with rating 8.02
# [✓] Inserted anime 73: Full Metal Panic! The Second Raid with rating 7.91
# [✓] Inserted anime 74: Gakuen Alice with rating 7.64
# [✓] Inserted anime 75: Soukyuu no Fafner: Dead Aggressor with rating 7.25
# [✓] Inserted anime 76: Mahou Shoujo Lyrical Nanoha with rating 7.41
# [✓] Inserted anime 77: Mahou Shoujo Lyrical Nanoha A's with rating 7.95
# [!] Failed to get staff for anime 78: 404 Client Error: Not Found for url: https://api.jikan.moe/v4/anime/78/staff
# [✓] Inserted anime 79: Shuffle! with rating 7
# [✓] Inserted anime 80: Kidou Senshi Gundam with rating 7.76
# [✓] Inserted anime 81: Kidou Senshi Gundam: Dai 08 MS Shoutai with rating 8
# [✓] Inserted anime 82: Kidou Senshi Gundam 0080: Pocket no Naka no Sensou with rating 7.99
# [✓] Inserted anime 83: Kidou Senshi Gundam: Dai 08 MS Shoutai - Miller's Report with rating 6.75
# [✓] Inserted anime 84: Kidou Senshi Gundam 0083: Stardust Memory with rating 7.22
# [✓] Inserted anime 85: Kidou Senshi Zeta Gundam with rating 7.89
# [✓] Inserted anime 86: Kidou Senshi Gundam ZZ with rating 6.67
# [✓] Inserted anime 87: Kidou Senshi Gundam: Gyakushuu no Char with rating 7.68
# [✓] Inserted anime 88: Kidou Senshi Gundam F91 with rating 6.59
# [✓] Inserted anime 89: Kidou Senshi Victory Gundam with rating 6.71
# [✓] Inserted anime 90: Shin Kidou Senki Gundam Wing with rating 7.67
# [✓] Inserted anime 91: Shin Kidou Senki Gundam Wing: Endless Waltz with rating 7.73
# [✓] Inserted anime 92: Kidou Shinseiki Gundam X with rating 7.33
# [✓] Inserted anime 93: Kidou Senshi Gundam SEED with rating 7.74
# [✓] Inserted anime 94: Kidou Senshi Gundam SEED Destiny with rating 7.17
# [✓] Inserted anime 95: Turn A Gundam with rating 7.79
# [✓] Inserted anime 96: Kidou Butouden G Gundam with rating 7.58
# [✓] Inserted anime 97: Last Exile with rating 7.78
# [✓] Inserted anime 98: Mai-HiME with rating 7.4
# [✓] Inserted anime 99: Mai-Otome with rating 7.27
# [✓] Inserted anime 100: Shin Shirayuki-hime Densetsu Prétear with rating 7.15

# %%
conn.close()
